# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Solution 1

# %%
class Solution:
    def firstMissingPositive(self, nums: List[int]) -> int:
        n=len(nums)
        l=set(range(1,n+2))

        for i in nums:
            if i in l:
                l.remove(i)
                

        return min(l)
